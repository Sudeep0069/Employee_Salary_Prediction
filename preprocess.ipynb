# %%
import pandas as pd

df = pd.read_csv("data.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts())
    print()
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64
#
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64
#
# fnlwgt
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 436163     1
# 320084     1
# 125976     1
# 211349     1
# 120478     1
# Name: count, Length: 28523, dtype: int64
#
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# ...

# %%
df["workclass"] = df["workclass"].replace("?", "Unknown")
df["occupation"] = df["occupation"].replace("?", "Unknown")
df["native-country"] = df["native-country"].replace("?", "Unknown")

df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Unknown  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# Create dictionary mapping
df[["education", "educational-num"]].drop_duplicates().sort_values("educational-num")
# Out:
#         education  educational-num
# 779     Preschool                1
# 323       1st-4th                2
# 37        5th-6th                3
# 9         7th-8th                4
# 54            9th                5
# 5            10th                6
# 0            11th                7
# 173          12th                8
# 1         HS-grad                9
# 3    Some-college               10
# 41      Assoc-voc               11
# 2      Assoc-acdm               12
# 11      Bachelors               13
# 15        Masters               14
# 7     Prof-school               15
# 19      Doctorate               16

# %%
df = df.drop("educational-num", axis=1)

df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18       Unknown  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# ...

# %%
df = df[~df["workclass"].isin(["Without-pay", "Never-worked"])]
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18       Unknown  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# ...

# %%
# income distribution per education category
edu_income_dist = (
    df[df["education"].isin(["Preschool", "1st-4th", "5th-6th"])]
    .groupby(["education", "income"])
    .size()
    .unstack(fill_value=0)
)

# add percentage column for clarity
edu_income_dist["% >50K"] = edu_income_dist[">50K"] / edu_income_dist.sum(axis=1) * 100

print(edu_income_dist)
# Out:
# income     <=50K  >50K    % >50K
# education
# 1st-4th      239     8  3.238866
# 5th-6th      482    27  5.304519
# Preschool     82     1  1.204819

# %%
df.loc[:, "education"] = df["education"].replace(
    ["Preschool", "1st-4th", "5th-6th"], "Low-education"
)
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18       Unknown  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  48811.000000  4.881100e+04  48811.000000  48811.000000    48811.000000
# mean      38.643707  1.896683e+05   1079.613018     87.519227       40.427527
# std       13.704928  1.056119e+05   7454.320956    403.044378       12.387637
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.175285e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.781540e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.376705e+05      0.000000      0.000000       45.000000
# max       90.000000  1.490400e+06  99999.000000   4356.000000       99.000000

# %%
df.describe(include="object")
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      48811     48811               48811           48811        48811
# unique         7        14                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15768               22365            6172        19708
#
#          race gender native-country income
# count   48811  48811          48811  48811
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    41736  32629          43802  37126

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_cols = df.select_dtypes(["number"])

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], bins=50, kde=False)
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
import numpy as np

log_cols = ["capital-gain", "capital-loss"]

plt.subplot(1, 2, 2)
for col in log_cols:
    sns.histplot(np.log1p(df[col]), bins=50, kde=False)
    plt.title(f"Histogram (log1p) of {col}")
    plt.tight_layout()
    plt.show()

# %%
# remove outliers
df = df[(df.age <= 75) & (df.age >= 17)]

plt.boxplot(df.age)
plt.show()

# %%
# Required libraries
import pandas as pd
from sklearn.calibration import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# 1️⃣ Split features and target
X = df.drop("income", axis=1)
y = df["income"]

# 2️⃣ Identify categorical and numeric columns
cat_cols = X.select_dtypes(include="object").columns.tolist()
num_cols = X.select_dtypes(include=["int64", "float64"]).columns.tolist()

# 3️⃣ One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=cat_cols, drop_first=True)

# Label encode income (0, 1)
le = LabelEncoder()
y_encoded = le.fit_transform(df["income"])

# 4️⃣ Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# 5️⃣ Scale numeric columns (needed for LogisticRegression, KNN, SVM)
scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# 6️⃣ Define models
models = {
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "XGBoost": XGBClassifier(
        use_label_encoder=False, eval_metric="logloss", random_state=42
    ),
    "GradientBoosting": GradientBoostingClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
}

# 7️⃣ Train models and print accuracy
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    results[name] = acc
    print(f"{name}: Accuracy = {acc:.4f}")
    print(classification_report(y_test, y_pred))
# Out:
# LogisticRegression: Accuracy = 0.8525
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      7363
#            1       0.74      0.59      0.66      2325
#
#     accuracy                           0.85      9688
#    macro avg       0.81      0.76      0.78      9688
# weighted avg       0.85      0.85      0.85      9688
#
# RandomForest: Accuracy = 0.8521
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      7363
#            1       0.73      0.60      0.66      2325
#
#     accuracy                           0.85      9688
#    macro avg       0.81      0.77      0.78      9688
# weighted avg       0.85      0.85      0.85      9688
#
# KNN: Accuracy = 0.8279
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      7363
#            1       0.66      0.59      0.62      2325
#
# ...

# %%
plt.bar(results.keys(), results.values(), color="lime")
plt.ylabel("Accuracy Score")
plt.title("Model Comparison")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import joblib

# Identify best model
best_model_name = max(results, key=results.get)
print(f"Best model: {best_model_name} with accuracy {results[best_model_name]:.4f}")

# Save best model
best_model = models[best_model_name]
joblib.dump(best_model, "best_model.pkl")
# Out:
# Best model: CatBoost with accuracy 0.8731
# ['best_model.pkl']

# %%
# Save feature column order for prediction
joblib.dump(X_train.columns.tolist(), "feature_columns.pkl")
# Out:
# ['feature_columns.pkl']
